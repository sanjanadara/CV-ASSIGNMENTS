# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
#imgL = cv.imread('img1_L.jfif')
imgL = cv.imread('inLeft.pgm')
frame1=cv.cvtColor(imgL, cv.COLOR_BGR2GRAY)
imgR = cv.imread('inRight.pgm')
frame2=cv.cvtColor(imgR, cv.COLOR_BGR2GRAY)

block_size = 11
min_disp = 0
max_disp = 80
num_disp = max_disp - min_disp
uniquenessRatio = 5
speckleWindowSize = 200
speckleRange = 2
disp12MaxDiff = 0

stereo = cv.StereoSGBM_create(
    minDisparity=min_disp,
    numDisparities=num_disp,
    blockSize=block_size,
    uniquenessRatio=uniquenessRatio,
    speckleWindowSize=speckleWindowSize,
    speckleRange=speckleRange,
    disp12MaxDiff=disp12MaxDiff,
    P1=8 * 1 * block_size * block_size,
    P2=32 * 1 * block_size * block_size,
)
#stereo = cv.StereoBM_create(numDisparities=64,blockSize=15)
disparity = stereo.compute(frame1,frame2)
plt.imshow(disparity,'gray')
plt.show()

# %%
plt.imshow(frame1,'gray')
plt.show()

# %%
plt.imshow(frame2,'gray')
plt.show()

# %%
frame1.size
# Out:
# 1389720

# %%
frame2.size
# Out:
# 1389720

# %%
#img4.jfif
img = cv.imread('two.jpg')
frame=cv.cvtColor(img, cv.COLOR_BGR2GRAY)
print(frame.size)
frame.shape
# Out:
# 133644
# (222, 602)

# %%
arr = np.hsplit(frame, 2)

# %%
arr[0].shape
# Out:
# (222, 301)

# %%
frame_1 = arr[0]

# %%
frame_2 = arr[1]

# %%
plt.imshow(frame_1,'gray')
plt.show()

# %%
plt.imshow(frame_2,'gray')
plt.show()

# %%
stereo = cv.StereoBM_create(numDisparities=64,blockSize=15)
disparity = stereo.compute(frame_1,frame_2)
plt.imshow(disparity,'gray')
plt.show()
